# %% [markdown]
# # 量子論理ゲート
# 基本的なゲート操作を確認します。
#
# ## 今回学ぶこと
# 1. 量子論理ゲート
# 2. 実装例

# %%
from blueqat import Circuit
import math

# %% [markdown]
# ## 角度が固定された1量子ビットゲート
# ### I, X, Y, Z, H, S, S†, T, T†
# I, X, Y, Z, H, S, S†, T, T† ゲートは以下のように実装できます。
#
# | I | X | Y | Z | H | S | S†| T | T†|
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# |`i`|`x`|`y`|`z`|`h`|`s`|`sdg`|`t`|`tdg`|

# %% [markdown]
# ### I ゲート
# $$
# I = \begin{bmatrix}
# 1 & 0 \\
# 0& 1
# \end{bmatrix}
# $$

# %%
Circuit().i[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %%
Circuit().i[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### X ゲート
# $$
# X = \begin{bmatrix}
# 0 & 1 \\
# 1 & 0
# \end{bmatrix}
# $$

# %%
Circuit().x[0].m[:].run(shots=100)
# Out:
# Counter({'1': 100})

# %%
Circuit().x[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'X',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### Y ゲート
# $$
# Y = \begin{bmatrix}
# 0 & -i \\
# i & 0
# \end{bmatrix}
# $$

# %%
Circuit().y[0].m[:].run(shots=100)
# Out:
# Counter({'1': 100})

# %%
Circuit().y[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'Y',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### Z ゲート
# $$
# Z = \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# $$

# %%
Circuit().z[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %%
Circuit().z[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'Z',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### H ゲート
# $$
# H = \frac{1}{\sqrt{2}}\begin{bmatrix}
# 1 & 1 \\
# 1 & -1
# \end{bmatrix}
# $$

# %%
Circuit().h[0].m[:].run(shots=100)
# Out:
# Counter({'0': 50, '1': 50})

# %%
Circuit().h[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'H',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### S ゲート
# $$
# S = \begin{bmatrix}
# 1 & 0 \\
# 0 & i
# \end{bmatrix}
# $$

# %%
Circuit().s[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %%
Circuit().s[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'S',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### S† ゲート
# $$
# S^{\dagger} = \begin{bmatrix}
# 1 & 0 \\
# 0 & -i
# \end{bmatrix}
# $$

# %%
Circuit().sdg[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %% [markdown]
# ### T ゲート
# $$
# T = \begin{bmatrix}
# 1 & 0 \\
# 0 & e^{i\frac{\pi}{4}}
# \end{bmatrix}
# $$

# %%
Circuit().t[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %%
Circuit().t[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'T',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### T† ゲート
# $$
# T^{\dagger} = \begin{bmatrix}
# 1 & 0 \\
# 0 & -e^{i\frac{\pi}{4}}
# \end{bmatrix}
# $$

# %%
Circuit().tdg[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %% [markdown]
# ## 任意角度の回転ゲート
# 回転ゲートは好きな角度だけ回転させることができます。

# %% [markdown]
# ### Rx, Ry, Rz

# %% [markdown]
# Rx, Ry, Rz ゲートは以下のように実装できます。
#
# | Rx | Ry | Rz |
# |:-:|:-:|:-:|
# |`rx(θ)`|`ry(θ)`|`rz(θ)`|
#
# $\theta$ は各軸周りの回転角です。

# %% [markdown]
# ### Rx ゲート
# $$
# Rx(\theta) =
# \begin{bmatrix}
# \cos(\frac{\theta}{2}) & -i\sin(\frac{\theta}{2}) \\
# -i\sin(\frac{\theta}{2}) & \cos(\frac{\theta}{2})
# \end{bmatrix}
# $$

# %%
Circuit().rx(math.pi/2)[0].m[:].run(shots=100)
# Out:
# Counter({'1': 52, '0': 48})

# %%
Circuit().rx(math.pi/2)[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'RX',
#     'angle': 1.57,
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### Ry ゲート
# $$
# Ry(\theta) =
# \begin{bmatrix}
# \cos(\frac{\theta}{2}) & -\sin(\frac{\theta}{2}) \\
# \sin(\frac{\theta}{2}) & \cos(\frac{\theta}{2})
# \end{bmatrix}
# $$

# %%
Circuit().ry(math.pi/2)[0].m[:].run(shots=100)
# Out:
# Counter({'0': 53, '1': 47})

# %%
Circuit().ry(math.pi/2)[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'RY',
#     'angle': 1.57,
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### Rz ゲート
# $$
# Rz(\theta) =
# \begin{bmatrix}
# e^{-i\frac{\theta}{2}} & 0 \\
# 0 & e^{i\frac{\theta}{2}}
# \end{bmatrix}
# $$

# %%
Circuit().rz(math.pi/2)[0].m[:].run(shots=100)
# Out:
# Counter({'0': 100})

# %%
Circuit().rz(math.pi/2)[0].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 1,
#     'gate': 'RZ',
#     'angle': 1.57,
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}]},
#  1,
#  [1, 2],
#  [1, 2],
#  [],
#  [])

# %% [markdown]
# ### U ゲート
# U ゲートは以下のように実装できます。
#
#
# | U |
# |:-:|
# |`u(θ,φ,λ,γ)`|
#
# ## 旧バージョンのU1, U2, U3ゲートからの変更
# 古いバージョンのBlueqatのコードを使っている場合は、以下のように書き換えてください。
#
# - U1(θ) → RZ(θ)
# - U2(φ, λ) → U(π/2, φ, λ, -0.5 * (φ+λ))
# - U3(θ, φ, λ) → U(θ, φ, λ, -0.5 * (φ+λ))
#
# U ゲートは4つのパラメータを持ち、大域位相を含む任意の状態を作ることができます。
#
# $$
# U(\theta, \phi, \lambda, \gamma) = e^{i\gamma}  \begin{bmatrix}
# \cos(\frac{\theta}{2}) & -e^{i\lambda} \sin(\frac{\theta}{2}) \\
# e^{i\phi} \sin(\frac{\theta}{2}) & e^{i(\phi+\lambda)} \cos(\frac{\theta}{2})
# \end{bmatrix}
# $$

# %%
Circuit().u(math.pi/2, 0, math.pi, -math.pi/2)[0].m[:].run(shots=100)
# Out:
# Counter({'0': 55, '1': 45})

# %% [markdown]
# ## 2量子ビットゲート
# 2量子ビットゲートは、主に1量子ビットゲートに制御ビットを追加したものです。
#
# ### CX, CY, CZ
# CX, CY, CZ ゲートは以下のように実装できます。
#
# | CX | CY | CZ |
# |:-:|:-:|:-:|
# |`cx`または`cnot`|`cy`|`cz`|

# %% [markdown]
# ### CX ゲート

# %%
Circuit().cx[0,1].m[:].run(shots=100)
#or
Circuit().cnot[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %%
Circuit().cx[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 3, 'gate': '', 'angle': '', 'xpos': 1, 'ypos': 0.0, 'type': 'gate'},
#    {'num': 4,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'X',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 1.5,
#     'type': 'gate'},
#    {'num': 5,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2, 4],
#  [1, 2],
#  [(2, 3)],
#  [])

# %% [markdown]
# ### CY ゲート

# %%
Circuit().cy[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %%
Circuit().cy[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 3, 'gate': '', 'angle': '', 'xpos': 1, 'ypos': 0.0, 'type': 'gate'},
#    {'num': 4,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'Y',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 1.5,
#     'type': 'gate'},
#    {'num': 5,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2, 4],
#  [1, 2],
#  [(2, 3)],
#  [])

# %% [markdown]
# ### CZ ゲート

# %%
Circuit().cz[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %%
Circuit().cz[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 3,
#     'gate': 'CZ',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 0.0,
#     'type': 'gate'},
#    {'num': 4,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'Z',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 1.5,
#     'type': 'gate'},
#    {'num': 5,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2, 4],
#  [1, 2],
#  [(2, 3)],
#  [])

# %% [markdown]
# ### CRx, CRy, CRz
# CRx, CRy, CRz ゲートは以下のように実装できます。
#
# | CRx | CRy | CRz |
# |:-:|:-:|:-:|
# |`crx(θ)`|`cry(θ)`|`crz(θ)`|

# %% [markdown]
# ### CRx ゲート

# %%
Circuit().crx(math.pi/2)[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %% [markdown]
# ### CRy ゲート

# %%
Circuit().cry(math.pi/2)[0,1].m[:].run(shots=1000)
# Out:
# Counter({'00': 1000})

# %% [markdown]
# ### CRz ゲート

# %%
Circuit().crz(math.pi/2)[0,1].m[:].run(shots=1000)
# Out:
# Counter({'00': 1000})

# %% [markdown]
# ### CU
# CU ゲートは以下のように実装できます。
#
# | CU |
# |:-:|
# |`cu(θ,φ,λ,γ)`|

# %%
Circuit().cu(math.pi/2, 0, math.pi, -math.pi/2)[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %% [markdown]
# ## Swap ゲート
# Swap ゲートは2つの量子ビットの状態を入れ替えるゲートです。

# %%
Circuit().swap[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %%
Circuit().swap[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 3, 'gate': '', 'angle': '', 'xpos': 1, 'ypos': 0.0, 'type': 'gate'},
#    {'num': 4,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'SWAP',
#     'angle': '',
#     'xpos': 1,
#     'ypos': 1.5,
#     'type': 'gate'},
#    {'num': 5,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2, 4],
#  [1, 2],
#  [(2, 3)],
#  [])

# %% [markdown]
# ### Rxx, Ryy, Rzz
# Rxx, Ryy, Rzz ゲートは以下のように実装できます。
#
# | Rxx | Ryy | Rzz |
# |:-:|:-:|:-:|
# |`rxx(θ)`|`ryy(θ)`|`rzz(θ)`|

# %% [markdown]
# ### RXX ゲート
# $$
# Rxx(\theta) = \left(\begin{array}{cccc}
# \cos\theta &0&0&-i\sin\theta\\
# 0& \cos\theta &-i\sin\theta&0\\
# 0&-i\sin\theta& \cos\theta &0\\
# -i\sin\theta&0&0& \cos\theta
# \end{array}\right)\\
# $$

# %%
Circuit(2).rxx(math.pi/2)[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 57, '11': 43})

# %%
Circuit(2).rxx(math.pi/2)[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 3,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2],
#  [1],
#  [],
#  [])

# %% [markdown]
# ### RYY ゲート
# $$
# Ryy(\theta) = \left(\begin{array}{cccc}
# \cos\theta &0&0&i\sin\theta\\
# 0& \cos\theta &-i\sin\theta&0\\
# 0&-i\sin\theta& \cos\theta &0\\
# i\sin\theta&0&0& \cos\theta
# \end{array}\right)
# $$

# %%
Circuit(2).ryy(math.pi/2)[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 52, '11': 48})

# %%
Circuit(2).ryy(math.pi/2)[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 3,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2],
#  [1],
#  [],
#  [])

# %% [markdown]
# ### RZZ ゲート
# $$
# Rzz(\theta) = \left(\begin{array}{cccc}
# e^{\frac{\theta}{2}i} &0&0&0\\
# 0& e^{-\frac{\theta}{2}i} &0&0\\
# 0&0& e^{-\frac{\theta}{2}i} &0\\
# 0&0&0& e^{\frac{\theta}{2}i}
# \end{array}\right)
# $$

# %%
Circuit().rzz(math.pi/2)[0,1].m[:].run(shots=100)
# Out:
# Counter({'00': 100})

# %%
Circuit(2).rzz(math.pi/2)[0,1].run(backend="draw")
# Out:
# ({0: [{'num': 0,
#     'gate': 'q0',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 0.0,
#     'type': 'qubit'},
#    {'num': 2,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 0.0,
#     'type': 'measurement'}],
#   1: [{'num': 1,
#     'gate': 'q1',
#     'angle': '',
#     'xpos': 0,
#     'ypos': 1.5,
#     'type': 'qubit'},
#    {'num': 3,
#     'gate': 'M',
#     'angle': '',
#     'xpos': 8,
#     'ypos': 1.5,
#     'type': 'measurement'}]},
#  2,
#  [2],
#  [1],
#  [],
#  [])

# %% [markdown]
# ### CCX ゲート

# %%
Circuit().x[:2].ccx[0,1,2].m[:].run(shots=1)
# Out:
# Counter({'111': 1})
